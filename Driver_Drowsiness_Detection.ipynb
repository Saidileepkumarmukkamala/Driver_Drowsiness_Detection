# %%
# !pip install opendatasets

# %%
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
import warnings, cv2
warnings.filterwarnings('ignore')
from tqdm.notebook import tqdm
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import opendatasets as od
import os
import numpy as np

# %%
od.download('https://www.kaggle.com/datasets/serenaraju/yawn-eye-dataset-new')
# sdlpkmrmkkml
# b2577bd76fc2d8e36b92620b9bd93e27
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sdlpkmrmkkml
# Your Kaggle Key: ··········
# Downloading yawn-eye-dataset-new.zip to ./yawn-eye-dataset-new
# 100%|██████████| 161M/161M [00:08<00:00, 19.7MB/s]

# %%
train_dir = "/content/yawn-eye-dataset-new/dataset_new/train/"
test_dir = "/content/yawn-eye-dataset-new/dataset_new/test/"

# %%
def load_images(directory):
    images = []
    labels = []
    
    for category in os.listdir(directory):
        for filename in tqdm(os.listdir(directory+category)):
            image_path = os.path.join(directory,category,filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
            image = cv2.resize(image,(224,224))
            images.append(image)
            labels.append(category)
    
    images = np.array(images,dtype='float32')
    return images, labels

# %%
X_train, y_train = load_images(train_dir)
X_test, y_test = load_images(test_dir)
# Out:
#   0%|          | 0/617 [00:00<?, ?it/s]
#   0%|          | 0/617 [00:00<?, ?it/s]
#   0%|          | 0/617 [00:00<?, ?it/s]
#   0%|          | 0/616 [00:00<?, ?it/s]
#   0%|          | 0/109 [00:00<?, ?it/s]
#   0%|          | 0/109 [00:00<?, ?it/s]
#   0%|          | 0/106 [00:00<?, ?it/s]
#   0%|          | 0/109 [00:00<?, ?it/s]

# %%
X_train = X_train / 255.
X_test = X_test / 255.

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
cnn = Sequential()

cnn.add(Conv2D(filters=16,kernel_size=3,activation='relu',input_shape=(224,224,3)))
cnn.add(MaxPooling2D(pool_size=2))

cnn.add(Conv2D(filters=32,kernel_size=3,activation='relu',padding='same'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.5))

cnn.add(Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.2))

cnn.add(Conv2D(filters=128,kernel_size=3,activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))

cnn.add(Flatten())

cnn.add(Dense(units=128,activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))

cnn.add(Dense(units=4,activation='softmax'))

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 111, 111, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 55, 55, 32)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 55, 55, 32)       128
#  ormalization)
#
#  dropout (Dropout)           (None, 55, 55, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 53, 53, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 26, 26, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 12, 12, 128)       0
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 128)               2359424
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2,458,788
# Trainable params: 2,458,084
# Non-trainable params: 704
# _________________________________________________________________

# %%
cnn.compile(loss='categorical_crossentropy',optimizer='adam',metrics='accuracy')

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',patience=20,mode='max',verbose=1,restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',patience=5,mode='max',verbose=1,factor=0.1,min_lr=0.001)
checkpoint_filename = 'checkpoint/'
model_checkpoint = ModelCheckpoint(filepath=checkpoint_filename,monitor='val_accuracy',verbose=1,save_best_only=True,save_weights_only=True,mode='max')

r = cnn.fit(x=X_train,
            y=y_train,
            epochs=50,
            batch_size=32,
            validation_data=(X_test,y_test),
            callbacks=[early_stopping,reduce_lr,model_checkpoint])
# Out:
# Epoch 1/50
# 78/78 [==============================] - ETA: 0s - loss: 0.5971 - accuracy: 0.7454
# Epoch 1: val_accuracy improved from -inf to 0.25173, saving model to checkpoint/
# 78/78 [==============================] - 171s 2s/step - loss: 0.5971 - accuracy: 0.7454 - val_loss: 5.0148 - val_accuracy: 0.2517 - lr: 0.0010
# Epoch 2/50
# 78/78 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8366
# Epoch 2: val_accuracy did not improve from 0.25173
# 78/78 [==============================] - 156s 2s/step - loss: 0.3559 - accuracy: 0.8366 - val_loss: 4.3970 - val_accuracy: 0.2517 - lr: 0.0010
# Epoch 3/50
# 78/78 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8597
# Epoch 3: val_accuracy improved from 0.25173 to 0.41339, saving model to checkpoint/
# 78/78 [==============================] - 156s 2s/step - loss: 0.3185 - accuracy: 0.8597 - val_loss: 2.7363 - val_accuracy: 0.4134 - lr: 0.0010
# Epoch 4/50
# 78/78 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.8983
# Epoch 4: val_accuracy did not improve from 0.41339
# 78/78 [==============================] - 157s 2s/step - loss: 0.2384 - accuracy: 0.8983 - val_loss: 2.4679 - val_accuracy: 0.3903 - lr: 0.0010
# Epoch 5/50
# 78/78 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9137
# Epoch 5: val_accuracy did not improve from 0.41339
# 78/78 [==============================] - 153s 2s/step - loss: 0.2058 - accuracy: 0.9137 - val_loss: 4.7251 - val_accuracy: 0.3741 - lr: 0.0010
# Epoch 6/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9453
# Epoch 6: val_accuracy improved from 0.41339 to 0.48499, saving model to checkpoint/
# 78/78 [==============================] - 156s 2s/step - loss: 0.1441 - accuracy: 0.9453 - val_loss: 1.8561 - val_accuracy: 0.4850 - lr: 0.0010
# Epoch 7/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9465
# Epoch 7: val_accuracy did not improve from 0.48499
# 78/78 [==============================] - 160s 2s/step - loss: 0.1369 - accuracy: 0.9465 - val_loss: 2.2685 - val_accuracy: 0.4596 - lr: 0.0010
# Epoch 8/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9627
# Epoch 8: val_accuracy improved from 0.48499 to 0.63279, saving model to checkpoint/
# 78/78 [==============================] - 154s 2s/step - loss: 0.1008 - accuracy: 0.9627 - val_loss: 0.7989 - val_accuracy: 0.6328 - lr: 0.0010
# Epoch 9/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9355
# Epoch 9: val_accuracy improved from 0.63279 to 0.83141, saving model to checkpoint/
# 78/78 [==============================] - 155s 2s/step - loss: 0.1609 - accuracy: 0.9355 - val_loss: 0.5025 - val_accuracy: 0.8314 - lr: 0.0010
# Epoch 10/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9603
# Epoch 10: val_accuracy improved from 0.83141 to 0.90531, saving model to checkpoint/
# 78/78 [==============================] - 158s 2s/step - loss: 0.1057 - accuracy: 0.9603 - val_loss: 0.2455 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 11/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9570
# Epoch 11: val_accuracy improved from 0.90531 to 0.97229, saving model to checkpoint/
# 78/78 [==============================] - 157s 2s/step - loss: 0.1072 - accuracy: 0.9570 - val_loss: 0.0965 - val_accuracy: 0.9723 - lr: 0.0010
# Epoch 12/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9838
# Epoch 12: val_accuracy did not improve from 0.97229
# 78/78 [==============================] - 159s 2s/step - loss: 0.0520 - accuracy: 0.9838 - val_loss: 0.1654 - val_accuracy: 0.9515 - lr: 0.0010
# Epoch 13/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9615
# Epoch 13: val_accuracy did not improve from 0.97229
# 78/78 [==============================] - 158s 2s/step - loss: 0.1100 - accuracy: 0.9615 - val_loss: 0.1489 - val_accuracy: 0.9353 - lr: 0.0010
# Epoch 14/50
# 78/78 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.
val_accuracy did not improve from 0.98152
# 78/78 [==============================] - 141s 2s/step - loss: 0.0413 - accuracy: 0.9878 - val_loss: 0.0875 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 37/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9959
# Epoch 37: val_accuracy did not improve from 0.98152
# 78/78 [==============================] - 140s 2s/step - loss: 0.0192 - accuracy: 0.9959 - val_loss: 0.1351 - val_accuracy: 0.9492 - lr: 0.0010
# Epoch 38/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9882
# Epoch 38: val_accuracy did not improve from 0.98152
# 78/78 [==============================] - 140s 2s/step - loss: 0.0405 - accuracy: 0.9882 - val_loss: 0.0527 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 39/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9882
# Epoch 39: val_accuracy did not improve from 0.98152
# 78/78 [==============================] - 141s 2s/step - loss: 0.0331 - accuracy: 0.9882 - val_loss: 0.0922 - val_accuracy: 0.9700 - lr: 0.0010
# Epoch 40/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9911
# Epoch 40: val_accuracy improved from 0.98152 to 0.99076, saving model to checkpoint/
# 78/78 [==============================] - 140s 2s/step - loss: 0.0242 - accuracy: 0.9911 - val_loss: 0.0351 - val_accuracy: 0.9908 - lr: 0.0010
# Epoch 41/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9947
# Epoch 41: val_accuracy did not improve from 0.99076
# 78/78 [==============================] - 141s 2s/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0564 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 42/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9919
# Epoch 42: val_accuracy did not improve from 0.99076
# 78/78 [==============================] - 140s 2s/step - loss: 0.0258 - accuracy: 0.9919 - val_loss: 0.1890 - val_accuracy: 0.9492 - lr: 0.0010
# Epoch 43/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9931
# Epoch 43: val_accuracy did not improve from 0.99076
# 78/78 [==============================] - 141s 2s/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.0360 - val_accuracy: 0.9861 - lr: 0.0010
# Epoch 44/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9976
# Epoch 44: val_accuracy did not improve from 0.99076
# 78/78 [==============================] - 139s 2s/step - loss: 0.0115 - accuracy: 0.9976 - val_loss: 0.0351 - val_accuracy: 0.9838 - lr: 0.0010
# Epoch 45/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9927
# Epoch 45: val_accuracy did not improve from 0.99076
# 78/78 [==============================] - 139s 2s/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.0344 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 46/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9955
# Epoch 46: val_accuracy improved from 0.99076 to 0.99307, saving model to checkpoint/
# 78/78 [==============================] - 140s 2s/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0282 - val_accuracy: 0.9931 - lr: 0.0010
# Epoch 47/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9984
# Epoch 47: val_accuracy did not improve from 0.99307
# 78/78 [==============================] - 140s 2s/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0271 - val_accuracy: 0.9931 - lr: 0.0010
# Epoch 48/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9968
# Epoch 48: val_accuracy did not improve from 0.99307
# 78/78 [==============================] - 141s 2s/step - loss: 0.0127 - accuracy: 0.9968 - val_loss: 0.1091 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 49/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9927
# Epoch 49: val_accuracy did not improve from 0.99307
# 78/78 [==============================] - 140s 2s/step - loss: 0.0187 - accuracy: 0.9927 - val_loss: 0.0480 - val_accuracy: 0.9861 - lr: 0.0010
# Epoch 50/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9805
# Epoch 50: val_accuracy did not improve from 0.99307
# 78/78 [==============================] - 140s 2s/step - loss: 0.0608 - accuracy: 0.9805 - val_loss: 0.0805 - val_accuracy: 0.9769 - lr: 0.0010

# %%
cnn.load_weights(checkpoint_filename)

# %%
plt.figure(figsize=(12,8))
plt.plot(r.history['loss'],'r',label='train loss')
plt.plot(r.history['val_loss'],'b',label='test loss')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Loss Graph')
plt.legend();

# %%
plt.figure(figsize=(12,8))
plt.plot(r.history['accuracy'],'r',label='train accuracy')
plt.plot(r.history['val_accuracy'],'b',label='test accuracy')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Graph')
plt.legend();

# %%
cnn.save('./model.h5')
